# %% [markdown]
# # LEARNING ABOUT ROWS AND COLUMNS AND HOW TO EXTRACT DATA:

# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv") 
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
df.shape #to know the rows and columns of the dataframe
# Out:
# (64461, 61)

# %%
df.columns #to know how many columns are there
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# ## Slicing of the dataframe with ":" and loc is used for rows

# %%
df.loc[:4, 'Hobbyist':'Country']
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
#
#               Country
# 0             Germany
# 1      United Kingdom
# 2  Russian Federation
# 3             Albania
# 4       United States

# %% [markdown]
# # LEARNING ABOUT INDEXES

# %% [markdown]
# ### In the dataframe we have respondant as ID so we will change the default index to Respondant

# %%
df = pd.read_csv("survey_results_public.csv", index_col = "Respondent")

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %% [markdown]
# ### what if we want to know what hobbyist mean without looking at the schema dataframe then we will use the following :

# %%
schema_df = pd.read_csv("survey_results_schema.csv",  index_col='Column')

# %%
schema_df #now we can see that the index have been changed to column
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %% [markdown]
# ### Now we can use .loc function to know what hobbyist and other means

# %%
schema_df.loc["CurrencyDesc"]
# Out:
# QuestionText    Which currency do you use day-to-day? If your ...
# Name: CurrencyDesc, dtype: object

# %%
schema_df.loc["CurrencyDesc", "QuestionText"]
# Out:
# "Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in."

# %%
schema_df.sort_index() #getting index in order
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                          QuestionText
# Column
# YearsCodePro        NOT including education, how many years have y...
# YearsCode           Including any education, how many years have y...
# WorkWeekHrs         On average, how many hours per week do you wor...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# ...                                                               ...
# ConvertedComp       Salary converted to annual USD salaries using ...
# CompTotal           What is your current total compensation (salar...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# Age1stCode          At what age did you write your first line of c...
# Age                 What is your age (in years)? If you prefer not...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index(inplace=True) #to make the schema dataframe sort permanently

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %% [markdown]
# # FILTERING DATA FROM SERIES OF OBJECTS AND DATAFRAME

# %% [markdown]
# #### we are filtering the data with high salaries

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary].head()
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 8           I am a developer by profession      Yes  36.0         12   Yearly
# 16          I am a developer by profession      Yes  45.0          8  Monthly
# 17          I am a developer by profession      Yes  25.0         14   Yearly
# 18          I am a developer by profession      Yes  32.0         12  Monthly
# 19          I am a developer by profession       No  24.0         15   Yearly
#
#             CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 8            116000.0       116000.0   United States  United States dollar
# 16             7000.0       108576.0  United Kingdom        Pound sterling
# 17            79000.0        79000.0   United States  United States dollar
# 18           105000.0      1260000.0   United States  United States dollar
# 19            83400.0        83400.0   United States  United States dollar
#
# ...

# %%
df.loc[high_salary, ['Country','YearsCode' ,'LanguageWorkedWith']]
# Out:
#                    Country YearsCode  \
# Respondent
# 8            United States        17
# 16          United Kingdom        37
# 17           United States         7
# 18           United States        19
# 19           United States         9
# ...                    ...       ...
# 65586        United States        25
# 65589        United States        10
# 65602        United States        15
# 65604        United States         7
# 65617              Germany         9
#
#                                            LanguageWorkedWith
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                                                       ...
# ...

# %% [markdown]
# #### narrowing down the filter

# %%
countries = ['United States', 'United Kingdom','Germany','India']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62464             India
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 28658, dtype: object

# %% [markdown]
# ### Making of another filter in which language worker with is python

# %%
python = df['LanguageWorkedWith'].str.contains('Python', na=False) # we used string, na because there are some values with NAN

# %%
df.loc[python, 'LanguageWorkedWith'] #giving the data of people who knows python
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
python
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %% [markdown]
# # MODIFYING AND UPDATE WITHIN DATAFRAME

# %% [markdown]
# ### UPDATING COLUMNS

# %%
# coverting the CovertedComp to salaries in usd
df.rename(columns={'ConvertedComp':'SalriesUSD'}, inplace=True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  SalriesUSD             Country  \
# Respondent
# 1                  13  Monthly        NaN         NaN             Germany
# 2                  19      NaN        NaN         NaN      United Kingdom
# 3                  15      NaN        NaN         NaN  Russian Federation
# 4                  18      NaN        NaN         NaN             Albania
# 5                  16      NaN        NaN         NaN       United States
#
# ...

# %%
df['SalriesUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalriesUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# now in hobbyist coverting yes and no to true and false
df['Hobbyist']=df['Hobbyist'].map({'Yes':'True','No':'Falso'})

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        Falso
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# # SORTING OF DATA

# %% [markdown]
# ### SORTING THE DATA BY COUNTRIES

# %%
df.sort_values(by=['Country','SalriesUSD'],ascending=[True, False] , inplace=True) #for country ascending is true and for SalriesUSD is false

# %%
df[['Country','SalriesUSD']].head(20)
# Out:
#                 Country  SalriesUSD
# Respondent
# 62788       Afghanistan   1000000.0
# 65381       Afghanistan   1000000.0
# 65456       Afghanistan   1000000.0
# 38672       Afghanistan    231192.0
# 28374       Afghanistan    130000.0
# 9839        Afghanistan     23328.0
# 63848       Afghanistan     23328.0
# 51862       Afghanistan     20950.0
# 51509       Afghanistan     20220.0
# 44484       Afghanistan     18660.0
# 15422       Afghanistan     18000.0
# 2932        Afghanistan     16335.0
# 26540       Afghanistan     13992.0
# 57269       Afghanistan     10884.0
# 26775       Afghanistan      8016.0
# 30568       Afghanistan      5448.0
# 30522       Afghanistan      4668.0
# 28811       Afghanistan      4509.0
# 34969       Afghanistan      4356.0
# 26857       Afghanistan      2328.0

# %% [markdown]
# ### to see the 10 highest salaries from our survey

# %%
df["SalriesUSD"].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalriesUSD, dtype: float64

# %%
df.nlargest(10,"SalriesUSD")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession    Falso  26.0
# 54263                          I am a developer by profession     True  29.0
# 43430                          I am a developer by profession     True  33.0
# 59279                          I am a developer by profession     True   NaN
# 46711                          I am a developer by profession     True   NaN
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
#
#                       Age1stCode CompFreq     CompTotal  SalriesUSD  \
# Respondent
# ...

# %% [markdown]
# # *GROUPING AND AGGREGATING DATA

# %% [markdown]
# ##### WE WILL BE COMBINING MULTIPLE PIECES OF DATA INTO SINGLE RESULT(EG: MEAN,MEDIAN,Z ARE SOME AGGREGATE FUNCTIONS

# %%
df["SalriesUSD"].head(15)
# Out:
# Respondent
# 62788    1000000.0
# 65381    1000000.0
# 65456    1000000.0
# 38672     231192.0
# 28374     130000.0
# 9839       23328.0
# 63848      23328.0
# 51862      20950.0
# 51509      20220.0
# 44484      18660.0
# 15422      18000.0
# 2932       16335.0
# 26540      13992.0
# 57269      10884.0
# 26775       8016.0
# Name: SalriesUSD, dtype: float64

# %%
#finding the median salary of the data
df["SalriesUSD"].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age               29.0
# CompTotal      63000.0
# SalriesUSD     54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal    SalriesUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['Hobbyist']
# Out:
# Respondent
# 62788     True
# 65381    Falso
# 65456     True
# 38672    Falso
# 28374     True
#          ...
# 60055    Falso
# 61121     True
# 61570    Falso
# 61918     True
# 62605    Falso
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# ### To get the value_counts and % of the data

# %%
# how many answered true and how many false
df['Hobbyist'].value_counts()
# Out:
# True     50388
# Falso    14028
# Name: Hobbyist, dtype: int64

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4754
# Information systems, information technology, or system administration              4071
# A natural science (such as biology, chemistry, physics, etc.)                      2205
# Mathematics or statistics                                                          1849
# Web development or web design                                                      1789
# A business discipline (such as accounting, finance, marketing, etc.)               1375
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# I never declared a major                                                            453
# ...

# %%
df['UndergradMajor'].value_counts(normalize=True) #to get the % value
# Out:
# Computer science, computer engineering, or software engineering                   0.619316
# Another engineering discipline (such as civil, electrical, mechanical, etc.)      0.093225
# Information systems, information technology, or system administration             0.079831
# A natural science (such as biology, chemistry, physics, etc.)                     0.043240
# Mathematics or statistics                                                         0.036258
# Web development or web design                                                     0.035082
# A business discipline (such as accounting, finance, marketing, etc.)              0.026963
# A humanities discipline (such as literature, history, philosophy, etc.)           0.019747
# A social science (such as anthropology, psychology, political science, etc.)      0.018296
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)    0.014217
# ...

# %%
schema_df.loc['UndergradMajor']
# Out:
# QuestionText    What was your primary field of study?
# Name: UndergradMajor, dtype: object

# %% [markdown]
# ### Group By Functions:
# 1.split, 2.Apply Functions, 3.Combine Results

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Lesotho               1
# Chad                  1
# Kiribati              1
# Fiji                  1
# Mali                  1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37655                          I am a developer by profession    Falso   NaN
# 36976       I am not primarily a developer, but I write co...    Falso   NaN
# 3332                           I am a developer by profession     True   NaN
# 8457                           I am a developer by profession     True  22.0
# 21351                          I am a developer by profession    Falso  98.0
# ...                                                       ...      ...   ...
# 54757                                                     NaN     True   NaN
# 55407                                                     NaN     True   NaN
# 62464                                                     NaN     True   NaN
# 62954                                                     NaN     True   NaN
# 64236                                                     NaN     True   NaN
#
# ...

# %%
filt = df['Country']  == 'India'
df.loc[filt]['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   4545
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       867
# Information systems, information technology, or system administration              456
# Web development or web design                                                      280
# Mathematics or statistics                                                           75
# A natural science (such as biology, chemistry, physics, etc.)                       57
# A business discipline (such as accounting, finance, marketing, etc.)                53
# I never declared a major                                                            23
# A humanities discipline (such as literature, history, philosophy, etc.)             11
# A health science (such as nursing, pharmacy, radiology, etc.)                       10
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)       8
# ...

# %%
country_grp['UndergradMajor'].value_counts().loc['India']
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   4545
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       867
# Information systems, information technology, or system administration              456
# Web development or web design                                                      280
# Mathematics or statistics                                                           75
# A natural science (such as biology, chemistry, physics, etc.)                       57
# A business discipline (such as accounting, finance, marketing, etc.)                53
# I never declared a major                                                            23
# A humanities discipline (such as literature, history, philosophy, etc.)             11
# A health science (such as nursing, pharmacy, radiology, etc.)                       10
# A social science (such as anthropology, psychology, political science, etc.)         8
# ...

# %%
country_grp['SalriesUSD'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: SalriesUSD, Length: 183, dtype: float64

# %%
country_grp['SalriesUSD'].median().loc['India']
# Out:
# 10056.0

# %%
# for mean and median

country_grp[['SalriesUSD',]].agg(['mean','median']).loc[['India', 'United States']]
# Out:
#                   SalriesUSD
#                         mean    median
# Country
# India           28751.271364   10056.0
# United States  208826.496443  115000.0

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %% [markdown]
# ### Converting into percentage

# %%
country_respondents = df['Country'].value_counts()

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Lesotho               1                   0
# Chad                  1                   0
# Kiribati              1                   0
# Fiji                  1                   0
# Mali                  1                   0
#
# [183 rows x 2 columns]

# %% [markdown]
# ### Remaning the colomns

# %%
python_df.rename(columns={'Country':'NumRespondents', 'LanguageWorkedWith':'NumKnowsPython'})
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12469            5964
# India                     8403            2670
# United Kingdom            3896            1621
# Germany                   3890            1712
# Canada                    2191            1011
# ...                        ...             ...
# Lesotho                      1               0
# Chad                         1               0
# Kiribati                     1               0
# Fiji                         1               0
# Mali                         1               0
#
# [183 rows x 2 columns]

# %%
#python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
